# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
df = pd.read_csv("scrapped_data.csv")

# %%
# Displaying for check correct load database
df.head()
# Out:
#          Game Name System Full  Units(m)     Publisher   Developer  \
# 0          Pac-Man  Atari 2600       7.7         Atari       Atari
# 1         Pitfall!  Atari 2600       4.0    Activision  Activision
# 2          Frogger  Atari 2600       4.0  Parker Bros.      Konami
# 3  Missile Command  Atari 2600       2.5         Atari       Atari
# 4   Space Invaders  Atari 2600       2.0         Atari       Atari
#
#                                            Image_URL Release Date
# 0  https://www.vgchartz.com/games/boxart/3878609c...   01/03/1982
# 1  https://www.vgchartz.com/games/boxart/127822cc...   20/04/1982
# 2  https://www.vgchartz.com/games/boxart/7351891c...   01/01/1982
# 3  https://www.vgchartz.com/games/boxart/8855822c...   01/01/1981
# 4  https://www.vgchartz.com/games/boxart/7131076c...   01/01/1978

# %%
# Dispalying information about database columns and his type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27308 entries, 0 to 27307
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Game Name     27308 non-null  object
#  1   System Full   27308 non-null  object
#  2   Units(m)      27308 non-null  float64
#  3   Publisher     27308 non-null  object
#  4   Developer     27305 non-null  object
#  5   Image_URL     27308 non-null  object
#  6   Release Date  24333 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 1.5+ MB

# %%
# Exchange type column "Release Date" from object to date
df['Release Date'] = df['Release Date'].astype('datetime64[ns]')

# %%
# Displaying for check correct load database again
df.head()
# Out:
#          Game Name System Full  Units(m)     Publisher   Developer  \
# 0          Pac-Man  Atari 2600       7.7         Atari       Atari
# 1         Pitfall!  Atari 2600       4.0    Activision  Activision
# 2          Frogger  Atari 2600       4.0  Parker Bros.      Konami
# 3  Missile Command  Atari 2600       2.5         Atari       Atari
# 4   Space Invaders  Atari 2600       2.0         Atari       Atari
#
#                                            Image_URL Release Date
# 0  https://www.vgchartz.com/games/boxart/3878609c...   1982-01-03
# 1  https://www.vgchartz.com/games/boxart/127822cc...   1982-04-20
# 2  https://www.vgchartz.com/games/boxart/7351891c...   1982-01-01
# 3  https://www.vgchartz.com/games/boxart/8855822c...   1981-01-01
# 4  https://www.vgchartz.com/games/boxart/7131076c...   1978-01-01

# %%
# Checking how to display empty values in "Release Date" column
df[df['Release Date'].isnull()]
# Out:
#                                        Game Name System Full  Units(m)  \
# 16                             DatabaseTestingNA  Atari 2600       0.0
# 71                           Ocean City Defender  Atari 2600       0.0
# 124                                  Gibbéri:sh'  Atari 2600       0.0
# 170                                    Time Warp  Atari 2600       0.0
# 190                                  TestingGame  Atari 2600       0.0
# ...                                          ...         ...       ...
# 27296  Double Dragon Gaiden: Rise of the Dragons    Xbox One       0.0
# 27300                 Punch Club 2: Fast Forward    Xbox One       0.0
# 27302                                Music Racer    Xbox One       0.0
# 27306  Doom Eternal: The Ancient Gods - Part Two    Xbox One       0.0
# 27307                           VISCO Collection    Xbox One       0.0
#
#       Publisher           Developer  \
# 16      Unknown           TalonSoft
# 71      Unknown             Zellers
# ...

# %%
# Save to csv file
df.to_csv("scrapped_data_convert.csv", index = False)
